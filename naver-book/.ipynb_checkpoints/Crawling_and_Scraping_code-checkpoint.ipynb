# %% [markdown]
# * 참고자료 1 : https://webnautes.tistory.com/779
# * 참고자료 2 : https://webnautes.tistory.com/1239
# * 추가 공부 자료 1 (동적 페이지 다루기) : https://luminitworld.tistory.com/88
# * 추가 공부 자료 2 (동적 페이지 다루기) : https://velog.io/@lybin10/%EB%8F%99%EC%A0%81-%EC%9B%B9-%ED%8E%98%EC%9D%B4%EC%A7%80-%ED%81%AC%EB%A1%A4%EB%A7%81

# %%
import os
import pandas as pd
import urllib.request
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By

# %% [markdown]
# ## 🔹 코드 ver.1

# %% [markdown]
# * 정적 페이지 : 크롤링+스크레이핑 적용
# * 1페이지만 동작

# %%
# 이미지 저장할 폴더 만들기
if not os.path.isdir('Book_img'):
    os.mkdir('Book_img')

url = "https://book.naver.com/bestsell/bestseller_list.nhn"

driver = webdriver.Chrome(ChromeDriverManager().install())
driver.implicitly_wait(30)


# 네이버의 베스트셀러 웹페이지를 가져옵니다.
driver.get(url)
bsObject = BeautifulSoup(driver.page_source, 'html.parser')

book_info_dict = {'title':[], 'author':[], 'url':[], 'price':[]}
    
    
# 책의 상세 웹페이지 주소를 추출하여 리스트에 저장합니다.
book_page_urls = []
for index in range(0, 25):
    dl_data = bsObject.find('dt', {'id':"book_title_"+str(index)})
    link = dl_data.select('a')[0].get('href')
    book_page_urls.append(link)


# 메타 정보와 본문에서 필요한 정보를 추출합니다.
for book_page_url in book_page_urls:

    driver.get(book_page_url)
    bsObject = BeautifulSoup(driver.page_source, 'html.parser')

    title = bsObject.find('div', 'bookTitle_title_area__fspvB').h2.text
    book_info_dict['title'].append(title)

    author = bsObject.find('div', 'bookTitle_info_content__iHfCC').text
    book_info_dict['author'].append(author)

    image = bsObject.find('meta', {'property':'og:image'}).get('content')

    if ':' in title:
        img_title = title.replace(' : ', '_')
        save_img_name = f'Book_img/{img_title}.jpg' 
    else : 
        save_img_name = f'Book_img/{title}.jpg' 
    urllib.request.urlretrieve(image, save_img_name)

    url = bsObject.find('meta', {'property':'og:url'}).get('content')
    book_info_dict['url'].append(url)

    price = bsObject.find('div', 'bookSeller_price__opK_s').text
    book_info_dict['price'].append(price)

    print(title, author, image, url, price)
    print('\n')
# Out:
# [WDM] - Downloading: 100%|████████████████████████████████████████████████████████| 6.78M/6.78M [00:00<00:00, 12.0MB/s]
# C:\Users\Family\AppData\Local\Temp\ipykernel_25696\225301823.py:7: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# 헤어질 결심 각본 정서경,박찬욱 https://shopping-phinf.pstatic.net/main_3355622/33556223644.20230214162653.jpg https://search.shopping.naver.com/book/catalog/33556223644 13,500원
#
#
# 흔한남매 11 흔한남매 (원작),백난도 https://shopping-phinf.pstatic.net/main_3361369/33613699623.20230218110217.jpg https://search.shopping.naver.com/book/catalog/33613699623 13,050원
#
#
# 불편한 편의점 김호연 https://shopping-phinf.pstatic.net/main_3244499/32444990070.20230218110501.jpg https://search.shopping.naver.com/book/catalog/32444990070 12,600원
#
#
# 역행자 자청 https://shopping-phinf.pstatic.net/main_3255028/32550285396.20221004114149.jpg https://search.shopping.naver.com/book/catalog/32550285396 15,750원
#
#
# 계속 가보겠습니다 임은정 https://shopping-phinf.pstatic.net/main_3347482/33474829621.20221019124110.jpg https://search.shopping.naver.com/book/catalog/33474829621 16,200원
큰별쌤 최태성의 별별한국사 기출 500제 한국사능력검정시험 심화 최태성 https://shopping-phinf.pstatic.net/main_3347482/33474823628.20230131164134.jpg https://search.shopping.naver.com/book/catalog/33474823628 17,550원
#
#
# [예스리커버] 인플레이션에서 살아남기 오건영 https://shopping-phinf.pstatic.net/main_3248265/32482650730.20230218110542.jpg https://search.shopping.naver.com/book/catalog/32482650730 16,920원
#
#
# 어린이를 위한 초등 매일 글쓰기의 힘: 세줄쓰기 이은경 https://shopping-phinf.pstatic.net/main_3351836/33518366620.20230117163204.jpg https://search.shopping.naver.com/book/catalog/33518366620 9,000원

# %%
book_info_df = pd.DataFrame(book_info_dict)
book_info_df
# Out:
#                                           title         author  \
# 0                                     헤어질 결심 각본        정서경,박찬욱
# 1                                       흔한남매 11  흔한남매 (원작),백난도
# 2                                       불편한 편의점            김호연
# 3                                           역행자             자청
# 4                                     계속 가보겠습니다            임은정
# 5                                      마법천자문 53            유대영
# 6                             어서 오세요, 휴남동 서점입니다            황보름
# 7                              이상한 과자 가게 전천당 15       히로시마 레이코
# 8                                          작별인사            김영하
# 9                                   밥 프록터 부의 확신          밥 프록터
# 10                        원펀맨(One Punch Man) 25            ONE
# 11     ETS 토익 정기시험 기출문제집 1000 Vol 3 READING(리딩)            ETS
# 12                                        파친코 1            이민진
# 13                            기분을 관리하면 인생이 관리된다            김다슬
# 14                                   유럽 도시 기행 2            유시민
# 15  ETS 토익 정기시험 기출문제집 1000 Vol 3 LISTENING(리스닝)            ETS
# 16                        세상의 마지막 기차역 (리커버 에디션)        무라세 다케시
# 17                                        입지 센스       박성혜 (훨훨)
# 18                                    꽁꽁꽁 아이스크림            윤정주
# 19                                물고기는 존재하지 않는다          룰루 밀러
# 20             해커스 토익 기출보카 TOEIC VOCA(토익보카) 단어장      David Cho
# 21                                      에그박사 7             박송이
# 22     2022 큰별쌤 최태성의 별별한국사 기출 500제 한국사능력검정시험 심화            최태성
# 23                         [예스리커버] 인플레이션에서 살아남기            오건영
# 24                   어린이를 위한 초등 매일 글쓰기의 힘: 세줄쓰기            이은경
#
#                                                   url    price
# 0   https://search.shopping.naver.com/book/catalog...  13,500원
# 1   https://search.shopping.naver.com/book/catalog...  13,050원
# 2   https://search.shopping.naver.com/book/catalog...  12,600원
# 3   https://search.shopping.naver.com/book/catalog...  15,750원
# 4   https://search.shopping.naver.com/book/catalog...  16,200원
# 5   https://search.shopping.naver.com/book/catalog...  12,600원
# 6   https://search.shopping.naver.com/book/catalog...  13,500원
# 7   https://search.shopping.naver.com/book/catalog...  11,700원
# 8   https://search.shopping.naver.com/book/catalog...  12,600원
# 9   https://search.shopping.naver.com/book/catalog...  14,400원
# 10  https://search.shopping.naver.com/book/catalog...   4,950원
# 11  https://search.shopping.naver.com/book/catalog...  16,020원
# 12  https://search.shopping.naver.com/book/catalog...  14,220원
# 13  https://search.shopping.naver.com/book/catalog...  15,840원
# 14  https://search.shopping.naver.com/book/catalog...  15,750원
# 15  https://search.shopping.naver.com/book/catalog...  16,020원
# 16  https://search.shopping.naver.com/book/catalog...  12,600원
# 17  https://search.shopping.naver.com/book/catalog...  18,000원
# 18  https://search.shopping.naver.com/book/catalog...  12,600원
# 19  https://search.shopping.naver.com/book/catalog...  15,300원
# 20  https://search.shopping.naver.com/book/catalog...  11,610원
# 21  https://search.shopping.naver.com/book/catalog...  13,050원
# 22  https://search.shopping.naver.com/book/catalog...  17,550원
# 23  https://search.shopping.naver.com/book/catalog...  16,920원
# 24  https://search.shopping.naver.com/book/catalog...   9,000원

# %%
book_info_df.to_excel('book_info.xlsx', encoding='utf-8', index=False)

# %% [markdown]
# ## 🔸코드 ver.2

# %% [markdown]
# * 동적 페이지 : 크롤링+스크레이핑 적용
# * 전체 페이지에서 동작

# %%
# 이미지 저장할 폴더 만들기
if not os.path.isdir('Book_img'):
    os.mkdir('Book_img')

    
url = "https://book.naver.com/bestsell/bestseller_list.nhn"

driver = webdriver.Chrome(ChromeDriverManager().install())
driver.implicitly_wait(40)


book_info_dict = {'title':[], 'author':[], 'url':[], 'price':[]}


# '네이버 : 베스트셀러 웹페이지' 가져오기
driver.get(url)
bsObject = BeautifulSoup(driver.page_source, 'html.parser')


for index_1 in range(0, 6):
    if index_1 != 0:
        driver.find_element(By.XPATH, f'//*[@id="section_bestseller"]/div[4]/a[{index_1}]').click()
        print('클릭 완료!')

    # 책의 상세 웹페이지 주소를 추출하여 리스트에 저장합니다.
    for index_2 in range(0, 25):
        driver.find_element(By.XPATH, f'//*[@id="book_title_{index_2}"]/a').click()
        driver.switch_to.window(driver.window_handles[1])
        
        bsObject = BeautifulSoup(driver.page_source, 'html.parser')
        
        try:
            title = bsObject.find('div', 'bookTitle_title_area__fspvB').h2.text
        except AttributeError as e:
            driver.close()
            driver.switch_to.window(driver.window_handles[0])
            
            driver.get('https://book.naver.com/bestsell/bestseller_list.nhn')
            driver.find_element(By.XPATH, f'//*[@id="section_bestseller"]/div[4]/a[{index_1}]').click()
            
            driver.find_element(By.XPATH, f'//*[@id="book_title_{index_2}"]/a').click()
            driver.switch_to.window(driver.window_handles[1])
            
            bsObject = BeautifulSoup(driver.page_source, 'html.parser')
            title = bsObject.find('div', 'bookTitle_title_area__fspvB').h2.text
        book_info_dict['title'].append(title)
            

        author = bsObject.find('div', 'bookTitle_info_content__iHfCC').text
        book_info_dict['author'].append(author)

        image = bsObject.find('meta', {'property':'og:image'}).get('content')

        if ':' in title:
            img_title = title.replace(': ', '_')
            save_img_name = f'Book_img/{img_title}.jpg' 
        else : 
            save_img_name = f'Book_img/{title}.jpg' 
        urllib.request.urlretrieve(image, save_img_name)

        url = bsObject.find('meta', {'property':'og:url'}).get('content')
        book_info_dict['url'].append(url)

        try:
            price = bsObject.find('div', 'bookSeller_price__opK_s').text
        except AttributeError as e:
            driver.find_element(By.XPATH, '//*[@id="__next"]/div/div[2]/div[2]/div[1]/div[3]/div/a').click()
            price = driver.find_element(By.XPATH, '//*[@id="book_section-seller"]/div[2]/ul/li[1]/div/a/span[3]/strong').text
        book_info_dict['price'].append(price)

        print(title, author, image, url, price)
        print('\n')
        
        driver.close()
        driver.switch_to.window(driver.window_handles[0])
# Out:
# C:\Users\Family\AppData\Local\Temp\ipykernel_25696\2518494460.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
#
#
#
# 저만치 혼자서 김훈 https://shopping-phinf.pstatic.net/main_3268297/32682971623.20230223070954.jpg https://search.shopping.naver.com/book/catalog/32682971623 13,500원

# %%
book_info_df = pd.DataFrame(book_info_dict)
book_info_df
# Out:
#             title         author  \
# 0       헤어질 결심 각본        정서경,박찬욱
# 1         흔한남매 11  흔한남매 (원작),백난도
# 2         불편한 편의점            김호연
# 3             역행자             자청
# 4       계속 가보겠습니다            임은정
# ..            ...            ...
# 145       만복이네 떡집            김리리
# 146       초등 사자소학            송재환
# 147  고양이 해결사 깜냥 1            홍민정
# 148         총 균 쇠      재레드 다이아몬드
# 149       저만치 혼자서             김훈
#
#                                                    url    price
# 0    https://search.shopping.naver.com/book/catalog...  13,500원
# 1    https://search.shopping.naver.com/book/catalog...  13,050원
# 2    https://search.shopping.naver.com/book/catalog...  12,600원
# 3    https://search.shopping.naver.com/book/catalog...  15,750원
# 4    https://search.shopping.naver.com/book/catalog...  16,200원
# ..                                                 ...      ...
# 145  https://search.shopping.naver.com/book/catalog...   9,900원
# 146  https://search.shopping.naver.com/book/catalog...  12,420원
# 147  https://search.shopping.naver.com/book/catalog...   9,900원
# 148  https://search.shopping.naver.com/book/catalog...  25,200원
# 149  https://search.shopping.naver.com/book/catalog...  13,500원
#
# [150 rows x 4 columns]

# %%
book_info_df.to_excel('book_info_2.xlsx', encoding='utf-8', index=False)

# %%
pd.read_excel('book_info_2.xlsx')
# Out:
#             title         author  \
# 0       헤어질 결심 각본        정서경,박찬욱
# 1         흔한남매 11  흔한남매 (원작),백난도
# 2         불편한 편의점            김호연
# 3             역행자             자청
# 4       계속 가보겠습니다            임은정
# ..            ...            ...
# 145       만복이네 떡집            김리리
# 146       초등 사자소학            송재환
# 147  고양이 해결사 깜냥 1            홍민정
# 148         총 균 쇠      재레드 다이아몬드
# 149       저만치 혼자서             김훈
#
#                                                    url    price
# 0    https://search.shopping.naver.com/book/catalog...  13,500원
# 1    https://search.shopping.naver.com/book/catalog...  13,050원
# 2    https://search.shopping.naver.com/book/catalog...  12,600원
# 3    https://search.shopping.naver.com/book/catalog...  15,750원
# 4    https://search.shopping.naver.com/book/catalog...  16,200원
# ..                                                 ...      ...
# 145  https://search.shopping.naver.com/book/catalog...   9,900원
# 146  https://search.shopping.naver.com/book/catalog...  12,420원
# 147  https://search.shopping.naver.com/book/catalog...   9,900원
# 148  https://search.shopping.naver.com/book/catalog...  25,200원
# 149  https://search.shopping.naver.com/book/catalog...  13,500원
#
# [150 rows x 4 columns]

# %% [markdown]
# ## 👉중복 title 가진 데이터 확인하기

# %%
book_info_df[book_info_df['title'].duplicated()]
# Out:
#                      title   author  \
# 25               헤어질 결심 각본  정서경,박찬욱
# 60   원펀맨(One Punch Man) 25      ONE
# 118  한 개의 기쁨이 천 개의 슬픔을 이긴다      조우성
#
#                                                    url    price
# 25   https://search.shopping.naver.com/book/catalog...  13,500원
# 60   https://search.shopping.naver.com/book/catalog...   4,950원
# 118  https://search.shopping.naver.com/book/catalog...  13,320원
